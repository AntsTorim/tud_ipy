# %%
with open("../cmp-bin-STT_majandus.csv", encoding="latin1") as f:
    lines = []
    for line in f:
        lines.append(line.split(","))

        
dup_cn = [x for x in lines[0] if lines[0].count(x) > 1]
print(dup_cn)
        
for l in lines:
    if len(l) != len(lines[0]): print(l, len(l))
# Out:
# []

# %%
import pandas as pd

sdf = pd.read_csv("../cmp-bin-STT_majandus.csv", sep=',', index_col=0, encoding='latin1')

# %%
sdf
# Out:
#              lapsi10  lapsi10-50  lapsi 50-100  lapsi ule 100  late ololu  \
# KURESSAARE         0           0             0              1           1
# ABRUKA             1           0             0              0           1
# ANIJALA            1           0             0              0           1
# ANSI               1           0             0              0           1
# ASTE               0           0             1              0           1
# ASTE alevik        0           0             0              1           1
# ASUKÃLA           0           1             0              0           1
# AULA-VINTRI        1           0             0              0           1
# EIKLA              0           1             0              0           1
# ENDLA              1           0             0              0           1
# HAAMSE             1           0             0              0           1
# HAKJALA            0           1             0              0           1
# ...

# %%
print(sdf.columns.duplicated())
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
# ...
