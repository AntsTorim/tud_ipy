# %% [markdown]
# # Analyzing Telia data

# %%
import pandas as pd
from kernel_fca_oo import ConfLexiSeriateSystem
import timeit
import matplotlib.pyplot as plt

# %%
KATALOOG = "..\\"
data = pd.read_csv(KATALOOG+"priv2.csv", sep=',', index_col=0, encoding='latin1')

# %% [markdown]
# Use Conformism Lexicographic system that is a small improvement over Frequency Lexicographic system described in my article.

# %%
system = ConfLexiSeriateSystem(data)

# %% [markdown]
# Time the execution, then execute actually.

# %%
# %%timeit
_, _ =  system.conceptchaincover(max_cc=100)
# Out:
# 2.42 s ± 34.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
cc, uc =  system.conceptchaincover(max_cc=100)

# %% [markdown]
# Plot the nr of concept chains vs data table yet uncovered graph.

# %%
plt.plot(uc)
plt.xlabel("Nr. of concept chains")
plt.ylabel("Uncovered ratio")
plt.show()

# %% [markdown]
# Print the concept chains in the order of importance. Chain is printed as a sequence of attribute names, followed by the number of objects having all the attributes upwards in the chain and a bar visualizing this number. After the chain is the ratio of data table (1s) yet to cover.

# %%
def conceptchain_tri_str(cc, maxlinelen=60):
    max_i = len(cc[0][1])
    #print(cc.local_maxima()) # Kuidas lisada?
    index = 0
    for (full_e, i), e in zip(cc, cc.extent_labels()):
        for kood in e:
            aine_str = str(kood) + '_' + '_'*(round(maxlinelen*(len(i)/max_i))-len(kood)) + str(len(i))
            print(aine_str)
        index += 1

for c, u in zip(cc, uc):
    #print(conceptchain_str(c))
    print(conceptchain_tri_str(c))
    print("Uncovered ratio: ", u)
    print("\n-----------------------------------------------------------\n")
# Out:
# service 11___________________________________________________411
# service 56_____________________________________316
# service 18_____________________________________315
# service 64__________________________________297
# service 44______________158
# service 43______________157
# service 65____________146
# service 61________114
# service 13_______108
# service 58_43
# service 10_35
# service 35_31
# service 51_11
# service 50_8
# service 23_5
# service 9_3
# service 63_2
# service 36_2
# service 41_2
# service 66_1
# service 21_1
# service 22_1
# None
# Uncovered ratio:  0.6589549889833176
#
# -----------------------------------------------------------
#
# service 35___________________________________________________306
# service 61____________________________190
# service 9_____65
# service 44_20
# service 43_20
# service 10_13
# service 41_8
# service 64_5
# service 65_5
# service 51_2
# service 22_1
# service 23_1
# service 27_1
# service 50_1
# service 25_1
# service 48_1
# None
# Uncovered ratio:  0.558231035568146
#
# -----------------------------------------------------------
#
# service 13___________________________________________________280
# service 21______________106
# service 23_28
# service 58_17
# service 9_4
# service 61_3
# service 32_2
# service 22_2
# service 27_1
# service 56_1
# service 50_1
# service 51_1
# service 12_1
# service 44_1
# service 43_1
# service 18_1
# None
# Uncovered ratio:  0.48740950582310355
#
# -----------------------------------------------------------
#
# service 10___________________________________________________252
# service 64_____60
# service 65___51
# service 44_12
# service 43_11
# service 48_5
# service 31_4
# service 26_3
# service 32_2
# service 34_2
# service 21_2
# service 57_1
# service 45_1
# service 66_1
# service 23_1
# None
# Uncovered ratio:  0.4231979855209317
#
# -----------------------------------------------------------
#
# service 36___________________________________________________97
# service 41______25
# service 51_3
# service 50_2
# service 58_2
# service 9_1
# service 22_1
# service 61_1
# service 30_1
# service 57_1
# service 6_1
# service 34_1
# service 49_1
# None
# Uncovered ratio:  0.40163676424299655
#
# -----------------------------------------------------------
#
# service 61___________________________________________________118
# service 44____25
# service 43____25
# service 23_6
# service 50_3
# service 51_3
# service 27_2
# service 53_1
# service 56_1
# service 32_1
# service 18_1
# service 58_1
# None
# Uncovered ratio:  0.3722064841045011
#
# -----------------------------------------------------------
#
# service 6____________________________________________________115
# service 58______28
# service 50_6
# service 51_4
# service 27_2
# service 26_1
# service 23_1
# service 25_1
# service 41_1
# service 9_1
# None
# Uncovered ratio:  0.34702549575070823
#
# -----------------------------------------------------------
#
# service 41___________________________________________________114
# service 9____________________54
# service 57_18
# service 23_5
# service 21_2
# service 66_1
# service 26_1
# service 22_1
# service 69_1
# service 32_1
# service 48_1
# None
# Uncovered ratio:  0.3157066414856783
#
# -----------------------------------------------------------
#
# service 50___________________________________________________105
# service 56_______28
# service 18_______28
# service 27_17
# service 58_5
# service 23_3
# service 51_2
# service 44_1
# service 43_1
# None
# Uncovered ratio:  0.28580421781554927
#
# -----------------------------------------------------------
#
# service 65___________________________________________________149
# service 34_13
# service 64_11
# service 31_6
# service 21_3
# service 9_2
# service 32_1
# service 66_1
# service 22_1
# None
# Uncovered ratio:  0.2563739376770538
#
# -----------------------------------------------------------
#
# service 23___________________________________________________78
# service 44_10
# service 43_10
# service 51_5
# service 27_3
# service 53_1
# service 24_1
# service 56_1
# service 25_1
# service 18_1
# None
# Uncovered ratio:  0.23890462700661
#
# -----------------------------------------------------------
#
# service 56___________________________________________________66
# service 18___________________________________________________66
# service 45_8
# service 66_2
# service 47_1
# service 26_1
# service 22_1
# service 34_1
# service 48_1
# None
# Uncovered ratio:  0.21576959395656278
#
# -----------------------------------------------------------
#
# service 21___________________________________________________98
# service 27_9
# service 31_3
# service 51_2
# service 9_1
# service 58_1
# None
# Uncovered ratio:  0.19782813975448538
#
# -----------------------------------------------------------
#
# service 58___________________________________________________89
# service 53_7
# service 48_2
# service 22_1
# service 57_1
# service 31_1
# None
# Uncovered ratio:  0.1819326408561536
#
# -----------------------------------------------------------
#
# service 48___________________________________________________87
# service 25_12
# service 26_5
# service 51_1
# service 30_1
# service 27_1
# None
# Uncovered ratio:  0.1650928548945546
#
# -----------------------------------------------------------
#
# service 51___________________________________________________77
# service 57_7
# service 32_3
# service 49_1
# service 34_1
# service 22_1
# None
# Uncovered ratio:  0.1509285489455461
#
# -----------------------------------------------------------
#
# service 66___________________________________________________72
# service 32_11
# service 9_3
# service 24_1
# service 30_1
# None
# Uncovered ratio:  0.13707900535096001
#
# -----------------------------------------------------------
#
# service 32___________________________________________________52
# service 34_9
# service 57_2
# service 69_1
# service 31_1
# None
# Uncovered ratio:  0.12684922883223165
#
# -----------------------------------------------------------
#
# service 31___________________________________________________68
# service 9_8
# service 64_1
# service 22_1
# service 27_1
# None
# Uncovered ratio:  0.11441611583254643
#
# -----------------------------------------------------------
#
# service 45___________________________________________________25
# service 25_4
# service 69_1
# service 14_1
# service 63_1
# service 27_1
# service 24_1
# None
# Uncovered ratio:  0.10906515580736544
#
# -----------------------------------------------------------
#
# service 22___________________________________________________38
# service 49_4
# service 34_2
# service 64_1
# service 57_1
# service 54_1
# service 7_1
# service 17_1
# None
# Uncovered ratio:  0.10135347812401636
#
# -----------------------------------------------------------
#
# service 26___________________________________________________45
# service 25_5
# service 53_1
# service 27_1
# None
# Uncovered ratio:  0.09316965690903369
#
# -----------------------------------------------------------
