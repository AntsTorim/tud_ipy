# %% [markdown]
# # Analyzing Telia data

# %%
import pandas as pd
from kernel_fca_oo import ConfLexiSeriateSystem, LexiSystem
import timeit
import matplotlib.pyplot as plt

# %%
KATALOOG = "..\\"
data = pd.read_csv(KATALOOG+"priv2.csv", sep=',', index_col=0, encoding='latin1')

# %%
data.describe()
# Out:
#         client 1   client 2   client 3   client 4   client 5   client 6  \
# count  73.000000  73.000000  73.000000  73.000000  73.000000  73.000000
# mean    0.041096   0.123288   0.219178   0.150685   0.164384   0.301370
# std     0.199886   0.331042   0.416552   0.360217   0.373188   0.462028
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 50%     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 75%     0.000000   0.000000   0.000000   0.000000   0.000000   1.000000
# max     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
#
#         client 7   client 8   client 9  client 10  ...  client 538  \
# count  73.000000  73.000000  73.000000  73.000000  ...   73.000000
# mean    0.095890   0.136986   0.164384   0.205479  ...    0.205479
# std     0.296479   0.346212   0.373188   0.406848  ...    0.406848
# min     0.000000   0.000000   0.000000   0.000000  ...    0.000000
# 25%     0.000000   0.000000   0.000000   0.000000  ...    0.000000
# 50%     0.000000   0.000000   0.000000   0.000000  ...    0.000000
# 75%     0.000000   0.000000   0.000000   0.000000  ...    0.000000
# max     1.000000   1.000000   1.000000   1.000000  ...    1.000000
#
#        client 539  client 540  client 541  client 542  client 543  client 544  \
# count   73.000000   73.000000   73.000000   73.000000   73.000000   73.000000
# mean     0.123288    0.219178    0.150685    0.136986    0.178082    0.219178
# std      0.331042    0.416552    0.360217    0.346212    0.385230    0.416552
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#        client 545  client 546  client 547
# count   73.000000   73.000000   73.000000
# mean     0.164384    0.082192    0.054795
# std      0.373188    0.276557    0.229154
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    0.000000
# 75%      0.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000
#
# [8 rows x 547 columns]

# %% [markdown]
# Use Conformism Lexicographic system that is a small improvement over Frequency Lexicographic system described in my article.

# %%
system = LexiSystem(data, refill=True)

# %% [markdown]
# Time the execution, then execute actually.

# %%
# %%timeit -n1
_, _ =  system.conceptchaincover(max_cc=100)
# Out:
# 1.05 s ± 24.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
cc, uc =  system.conceptchaincover(max_cc=100)

# %% [markdown]
# Plot the nr of concept chains vs data table yet uncovered graph.

# %%
cc_nrs = range(len(uc)+1)
plt.plot(cc_nrs, [1.0] + uc)
plt.xlabel("Nr. of concept chains")
plt.xticks(cc_nrs)
plt.ylabel("Uncovered ratio")
plt.yticks([x/10 for x in range(0, 11)])
plt.grid()
plt.show()

# %% [markdown]
# Print the concept chains in the order of importance. Chain is printed as a sequence of attribute names, followed by the number of objects having all the attributes upwards in the chain and a bar visualizing this number. After the chain is the ratio of data table (1s) yet to cover.

# %%
def conceptchain_tri_str(cc, maxlinelen=60):
    max_i = len(cc[0][1])
    #print(cc.local_maxima()) # Kuidas lisada?
    index = 0
    for (full_e, i), e in zip(cc, cc.extent_labels()):
        for kood in e:
            aine_str = str(kood) + '_' + '_'*(round(maxlinelen*(len(i)/max_i))-len(kood)) + str(len(i))
            print(aine_str)
        index += 1

        
def conceptchain_lat_str(cc):
    s_list = []
    for (full_e, i), e in zip(cc, cc.extent_labels()):
        s_e = "{" + ", ".join(str(x) for x in e) + "}"
        s_list.append(r"$\langle " + str(len(i)) + ", " + s_e + r" \rangle$")
    #print(s_list)
    result = ",\n".join(s_list) 
    return result
                             
        
for c, u in zip(cc, uc):
    #print(conceptchain_str(c))
    print(conceptchain_tri_str(c, maxlinelen=40))
    #print(conceptchain_lat_str(c))
    print("Uncovered ratio: ", u)
    print("\n----------------------------------\n")
# Out:
# service 11_______________________________411
# service 56______________________316
# service 18______________________315
# service 64____________________297
# service 44______158
# service 43______157
# service 65_____146
# service 61__114
# service 13__108
# service 58_43
# service 10_35
# service 35_31
# service 51_11
# service 50_8
# service 23_5
# service 9_3
# service 36_2
# service 63_2
# service 41_2
# service 66_1
# service 21_1
# service 22_1
# None
# Uncovered ratio:  0.6589549889833176
#
# ----------------------------------
#
# service 35_______________________________337
# service 61_________________________286
# service 9___95
# service 44_53
# service 43_52
# service 10_33
# service 41_20
# service 64_16
# service 65_16
# service 11_16
# service 51_5
# service 27_2
# service 23_2
# service 25_2
# service 50_2
# service 22_1
# service 48_1
# None
# Uncovered ratio:  0.5502045955303746
#
# ----------------------------------
#
# service 13_______________________________388
# service 18______________________________374
# service 56______________________________374
# service 21_______158
# service 23_45
# service 58_31
# service 9_10
# service 61_9
# service 32_3
# service 22_3
# service 43_1
# service 51_1
# service 27_1
# service 50_1
# service 44_1
# service 12_1
# None
# Uncovered ratio:  0.4416115832546427
#
# ----------------------------------
#
# service 64_______________________________386
# service 10___________________266
# service 65________________241
# service 44___119
# service 43___117
# service 66_18
# service 11_18
# service 48_4
# service 32_3
# service 23_2
# service 26_2
# service 21_2
# service 57_2
# service 34_1
# service 45_1
# service 31_1
# service 35_1
# None
# Uncovered ratio:  0.36480956877557447
#
# ----------------------------------
#
# service 9________________________________195
# service 41_____________106
# service 51_18
# service 50_15
# service 6_5
# service 58_3
# service 36_1
# service 30_1
# service 34_1
# service 57_1
# service 22_1
# service 61_1
# service 49_1
# None
# Uncovered ratio:  0.3303430909663204
#
# ----------------------------------
#
# service 61_______________________________426
# service 44__________205
# service 43__________202
# service 23_59
# service 51_25
# service 50_22
# service 27_15
# service 64_2
# service 11_2
# service 21_2
# service 49_2
# service 34_1
# service 17_1
# service 7_1
# service 57_1
# service 54_1
# service 22_1
# None
# Uncovered ratio:  0.28281397544853637
#
# ----------------------------------
#
# service 6________________________________116
# service 36_27
# service 61_27
# service 66_4
# service 64_3
# service 65_3
# service 21_3
# service 11_3
# service 34_2
# service 31_2
# service 32_1
# service 9_1
# service 22_1
# None
# Uncovered ratio:  0.25920679886685555
#
# ----------------------------------
#
# service 23_______________________________128
# service 51______48
# service 50____43
# service 35_5
# service 64_5
# service 11_5
# service 48_5
# service 27_4
# service 10_2
# service 61_2
# service 22_2
# service 34_1
# service 21_1
# None
# Uncovered ratio:  0.244255587031791
#
# ----------------------------------
#
# service 64_______________________________83
# service 31_______________________________83
# service 48_____29
# service 65____26
# service 34_8
# service 11_8
# service 26_3
# service 43_3
# service 44_3
# service 35_3
# service 30_1
# service 32_1
# service 10_1
# service 21_1
# service 61_1
# service 22_1
# None
# Uncovered ratio:  0.2241107963487567
#
# ----------------------------------
#
# service 58_______________________________186
# service 50__52
# service 18_48
# service 56_48
# service 30_2
# service 43_2
# service 35_2
# service 44_2
# service 11_2
# service 21_2
# service 13_2
# service 10_1
# service 53_1
# service 51_1
# service 26_1
# None
# Uncovered ratio:  0.1987724268177526
#
# ----------------------------------
#
# service 50_______________________________126
# service 27__________59
# service 64_25
# service 65_25
# service 11_25
# service 30_2
# service 35_2
# service 25_1
# service 43_1
# service 51_1
# service 48_1
# service 56_1
# service 18_1
# service 44_1
# service 26_1
# service 13_1
# None
# Uncovered ratio:  0.182247403210576
#
# ----------------------------------
#
# service 22_______________________________49
# service 26_8
# service 34_2
# service 45_2
# service 66_1
# service 48_1
# service 47_1
# service 56_1
# service 18_1
# service 10_1
# service 61_1
# None
# Uncovered ratio:  0.17359143846395972
#
# ----------------------------------
#
# service 65_______________________________351
# service 64_47
# service 11_47
# service 57_47
# service 36_7
# service 61_7
# service 49_2
# service 45_1
# service 25_1
# service 9_1
# service 35_1
# None
# Uncovered ratio:  0.15738117721120554
#
# ----------------------------------
#
# service 32_______________________________73
# service 34_18
# service 21_8
# service 66_4
# service 45_2
# service 43_2
# service 44_2
# service 35_2
# None
# Uncovered ratio:  0.14353163361661944
#
# ----------------------------------
#
# service 25_______________________________66
# service 66_8
# service 56_8
# service 18_8
# service 61_8
# service 13_8
# service 36_5
# service 43_1
# service 35_1
# service 23_1
# service 64_1
# service 42_1
# service 65_1
# service 20_1
# service 71_1
# service 10_1
# service 44_1
# service 14_1
# service 58_1
# service 41_1
# service 69_1
# service 11_1
# None
# Uncovered ratio:  0.13125590179414542
#
# ----------------------------------
#
# service 66_______________________________78
# service 18____________________57
# service 56____________________57
# service 41_16
# service 30_2
# service 43_2
# service 23_2
# service 44_2
# service 11_2
# service 61_2
# service 48_1
# service 62_1
# service 57_1
# service 58_1
# service 13_1
# None
# Uncovered ratio:  0.12118350645262826
#
# ----------------------------------
#
# service 53_______________________________47
# service 10________________29
# service 43_2
# service 56_2
# service 18_2
# service 44_2
# service 9_2
# service 70_2
# service 61_2
# service 13_2
# service 48_1
# service 35_1
# service 64_1
# service 65_1
# service 27_1
# service 26_1
# service 11_1
# service 41_1
# None
# Uncovered ratio:  0.11284230406043437
#
# ----------------------------------
#
# service 51_______________________________111
# service 11_18
# service 48_18
# service 36_1
# service 35_1
# service 64_1
# service 65_1
# service 56_1
# service 18_1
# service 50_1
# service 61_1
# service 13_1
# None
# Uncovered ratio:  0.10402895813660686
#
# ----------------------------------
#
# service 41_______________________________150
# service 36_30
# service 61_30
# service 21_12
# service 43_2
# service 51_2
# service 35_2
# service 23_2
# service 63_2
# service 56_2
# service 18_2
# service 50_2
# service 44_2
# service 58_2
# service 9_2
# service 25_1
# service 69_1
# None
# Uncovered ratio:  0.09505823103556815
#
# ----------------------------------

# %% [markdown]
# Ahel1 (baasteenused tavainimesele)
# s11: Internetiühendus kodus, s56: kõnepakett koos SMS, s18: kõned Eestis, s64: koduTV, s43,44: parkimisteenused
#
# Ahel2 (edasijõudnud kasutaja)
# s35: mobiili-id, s61: telefonikõned vähelevinud/teadmata operaatoritele, s9: mobiilne internet.
#
# Ahel3 (jagatav mobiilne internet, aga miks mitte TV??)
# s13: jagatav mobiilne internet,  s56: kõnepakett koos SMS, s18: kõned Eestis, s21: kõned erinevatele teenusnumbritele
#
# Ahel4 (TV vaataja internet)
# s64: koduTV, s10: interneti püsiühendus (ADSL), S65: TV salvestusteenus

# %%
match=[mob for mob, tv in zip(data.loc['service 13'], data.loc['service 64']) if mob==tv]
print(len(match))
print(sum(match))
print(sum(data.loc['service 13']))
print(sum(data.loc['service 64']))
# Out:
# 333
# 280
# 388
# 386

# %%
cleaned_matrix = data.T.drop(columns=["service 15", "service 29", "service 33", "service 37", "service 39", "service 59", "service 67"]) 
corr_matrix = cleaned_matrix.corr(method="spearman")
corr_matrix[30:40]
# Out:
#             service 1  service 2  service 3  service 4  service 5  service 6  \
# service 34   0.032695  -0.016125  -0.032338  -0.025978  -0.027980   0.048520
# service 35  -0.064607  -0.054214  -0.020487   0.104134   0.058621   0.004909
# service 36  -0.040347  -0.020118  -0.040347   0.014017   0.029385   0.069761
# service 38  -0.003673  -0.001832  -0.003673  -0.006936  -0.003178  -0.022202
# service 40  -0.005199  -0.002593  -0.005199  -0.009818  -0.004499  -0.031427
# service 41  -0.004660   0.069623  -0.004660   0.030123  -0.045647   0.011931
# service 42  -0.009039  -0.004507  -0.009039  -0.017068  -0.007821  -0.011696
# service 43  -0.037194  -0.039993   0.005819   0.103811  -0.019776  -0.054479
# service 44  -0.038111  -0.040436   0.004872   0.101960  -0.020578  -0.051183
# service 45  -0.022096  -0.011018   0.155646   0.054170  -0.019118   0.033153
#
#             service 7  service 8  service 9  service 10  ...  service 63  \
# service 34   0.097728  -0.022825   0.066619   -0.058948  ...   -0.006046
# service 35  -0.020487  -0.014460  -0.087407    0.023973  ...    0.052677
# service 36  -0.040347   0.050194   0.036756   -0.012367  ...    0.028885
# service 38  -0.003673  -0.002593  -0.031853    0.038832  ...   -0.009560
# service 40  -0.005199  -0.003670  -0.045088    0.054967  ...   -0.013533
# service 41  -0.052757   0.030658   0.449403    0.014271  ...    0.093797
# service 42  -0.009039  -0.006380  -0.005092    0.025018  ...    0.058965
# service 43   0.005819   0.004107  -0.045181    0.023169  ...    0.152933
# service 44   0.004872   0.003439  -0.038035    0.025763  ...    0.150374
# service 45  -0.022096  -0.015595   0.013901   -0.101139  ...    0.013662
#
#             service 64  service 65  service 66  service 68  service 69  \
# service 34   -0.097085   -0.122884    0.147427    0.047045   -0.026607
# service 35    0.067553    0.029423   -0.000590    0.007723    0.040632
# service 36    0.043123    0.083910    0.079891   -0.034909    0.084765
# service 38   -0.066265   -0.057270   -0.017453   -0.003178   -0.009168
# service 40   -0.027338   -0.017899   -0.024705   -0.004499   -0.012977
# service 41    0.001348    0.032028    0.007156    0.009839   -0.011631
# service 42   -0.009012    0.005487    0.007250   -0.007821    0.063136
# service 43    0.024565    0.048692    0.048610   -0.069397    0.229232
# service 44    0.023608    0.049231    0.054570   -0.070165    0.226722
# service 45   -0.099564   -0.060277    0.003286   -0.019118    0.018788
#
#             service 70  service 71  service 72  service 73
# service 34    0.007476   -0.061064   -0.022825   -0.016125
# service 35   -0.029731   -0.062489    0.047820    0.033783
# service 36   -0.047894    0.014017    0.050194   -0.020118
# service 38   -0.008761   -0.006936   -0.002593   -0.001832
# service 40   -0.012401   -0.009818   -0.003670   -0.002593
# service 41    0.041028    0.107970   -0.037236   -0.026306
# service 42   -0.021558    0.094076   -0.006380   -0.004507
# service 43    0.051183   -0.035424    0.004107    0.045796
# service 44    0.067539   -0.037180    0.003439    0.045294
# service 45    0.139994    0.054170   -0.015595   -0.011018
#
# [10 rows x 66 columns]

# %%
import seaborn as sns
sns.set_context("paper", font_scale=0.7)
sns.clustermap(corr_matrix, vmin=-1, vmax=1)

# %%
#data.loc['service 67']
